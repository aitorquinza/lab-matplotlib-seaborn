# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sqlalchemy import create_engine
import os

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.figure(figsize=(15,5))
plt.scatter(x, y, label = 'x', linewidth = 1, 
            s=40, color = 'blue')

# %%
plt.figure(figsize=(15,5))
plt.scatter(x, z, label = 'x', linewidth = 1, 
            s=40, color = 'blue')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(1, 2, figsize=(20, 15))
ax[0].scatter(x, y, label = 'x', linewidth = 1, 
            s=40, color = 'blue')
ax[1].scatter(x, z, label = 'x', linewidth = 1, 
            s=40, color = 'blue')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].scatter(x,y,label='x',s=20,color='blue',edgecolor='black')
ax[0].set_title('x, y', fontsize=20)
ax[1].scatter(x,z,label='x',s=20,color='blue',edgecolor='black')
ax[1].set_title('x, z', fontsize=20)
ax[1].set_xlabel('x', fontsize=20)
ax[1].set_ylabel('y', fontsize=20)
ax[0].set_xlabel('x', fontsize=20)
ax[0].set_ylabel('y', fontsize=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y = x**2
z = e**x
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].scatter(x,y,label='x',s=20,color='blue',edgecolor='black')
ax[0].set_title('normal scale', fontsize=40)
ax[1].scatter(x,z,label='x',s=20,color='blue',edgecolor='black')
ax[1].set_title('logarithmic scale', fontsize=40)
ax[1].set_xlabel('x', fontsize=20)
ax[1].set_ylabel('y', fontsize=20)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_ylabel('y', fontsize=20)
ax[0].set_xlabel('x', fontsize=20)
ax[0].set_ylabel('y', fontsize=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
driver   = 'mysql+pymysql:'
user     = 'ironhack'
password = ''
ip       = '127.0.0.1'
database = 'fitbit'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)
fitbit=pd.read_sql('SELECT* FROM fitbit2',engine)
fitbit
# Out:
#            Date  Calorie burned  Steps Distance  Floors Minutes Sedentary  \
# 0    2015-05-08            1934    905     0.65       0             1.355
# 1    2015-05-09            3631  18925    14.11       4               611
# 2    2015-05-10            3204  14228    10.57       1               602
# 3    2015-05-11            2673   6756     5.02       8               749
# 4    2015-05-12            2495    502     3.73       1               876
# ..          ...             ...    ...      ...     ...               ...
# 362  2016-05-03            3796  18588    14.13      16               599
# 363  2016-05-04            3525  16382    12.39      16               684
# 364  2016-05-05            3649  21913     16.4      19               701
# 365  2016-05-06            3539  19023    14.79      15               575
# 366  2016-05-07             304   9526     7.08       2               564
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
x = fitbit['Months_encoded'].sort_values().unique()
y = fitbit['Steps']
x_m = sorted(fitbit['Months_encoded'].unique())
y_m= fitbit.groupby(by="Months_encoded")['Steps'].median()
# by week
x_w = sorted(fitbit['Work_or_Weekend'].unique())
y_w = fitbit.groupby(by="Work_or_Weekend")['Steps'].median()
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
plt.sca(ax1)
plt.plot(x_m, y_m)
plt.title('MEDIAN STEPS BY MONTH_ENCODED', fontsize=10)
plt.sca(ax2)
plt.bar(x_w, y_w)
plt.title('MEDIAN STEPS BY WORK_OR_WEEKEND', fontsize=10)
plt.xticks((0,1), ("Weekend", "Weekday"), rotation=45)
plt.savefig('./figures/median-steps-month.pdf')
plt.savefig('./figures/median-steps-work.pdf')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
lst=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']# your code here
for i in lst:
    x = fitbit[i]
    y = fitbit['Steps']
    plt.figure(figsize=(17,6))
    plt.scatter(x,y,label='x',linewidth=1,s=40,color='red',edgecolor='black')
    plt.show()
    plt.savefig(f'figures/{i}_Steps.png', dpi=400,quality=100)
    plt.clf()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
driver   = 'mysql+pymysql:'
user     = 'ironhack'
password = ''
ip       = '127.0.0.1'
database = 'titanic'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)
titanic = pd.read_sql('SELECT * FROM titanic',engine)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes('int64', 'float64').head()
# Out:
#    PassengerId  Pclass  SibSp  Parch
# 0            1       3      1      0
# 1            2       1      1      0
# 2            3       3      0      0
# 3            4       1      1      0
# 4            5       3      0      0

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes('object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
ax = sns.barplot(x = titanic['Age'].sort_values().unique(), y = titanic.groupby('Age')['PassengerId'].count(), palette="Blues_d")
sns.set()
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig,(ax1, ax2, ax3) = plt.subplots(1, 3)
ax1 = sns.distplot(titanic['Age'], bins = (10), ax = ax1)
ax2 = sns.distplot(titanic['Age'], bins = (20), ax = ax2)
ax3 = sns.distplot(titanic['Age'], bins = (50), ax = ax3)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))

ax=sns.barplot(x = titanic['Age'].sort_values().unique(), y = titanic.groupby('Age')['PassengerId'].count(), palette="Blues_d")
sns.set()
plt.xlabel('Age')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig, ax=plt.subplots(figsize=(12,4))
plt.bar(titanic['Gender'].sort_values().unique(), titanic.groupby('Gender')['PassengerId'].count())
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
ax=sns.barplot(x = titanic['Gender'].sort_values().unique(), y = titanic.groupby('Gender')['PassengerId'].count())

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
fig, ax, = plt.subplots(figsize=(15,5))
ax=sns.barplot(x = titanic['Pclass'].sort_values().unique(), y = titanic.groupby('Pclass').agg({'PassengerId':'count'}))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-e7f50b8b4b56> in <module>
#       1 # your code here
#       2 fig, ax, = plt.subplots(figsize=(15,5))
# ----> 3 ax=sns.barplot(x = titanic['Pclass'].sort_values().unique(), y = titanic.groupby('Pclass').agg({'PassengerId':'count'}))
#
# /usr/local/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ...

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.catplot(x= 'Age',kind='box', data=titanic)

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The first quartile is between 0 to 21, second quantile is between 21 to 38, where 29 is the mean"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig, (ax1,ax2) =plt.subplots(1,2,figsize=(12,4))
ax1.boxplot(titanic['Age'])
ax2.bar(titanic['Age'].sort_values().unique(), titanic.groupby('Age')['PassengerId'].count())
# Out:
# <BarContainer object of 193 artists>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Fare'],titanic['Age'])

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x= 'Fare',y='Age',data=titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),xticklabels=titanic.corr().columns,yticklabels=titanic.corr().columns)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.jointplot('Age','Pclass',data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g=sns.FacetGrid(titanic, col="Gender")
g=g.map(plt.hist,"Age")
